# %% [markdown]
# # Kuis 2 Pembelajaran Mesin
#
# NIM     : 2041720140 <br>
# Nama    : Ananda Ayu Sekar Wiranti <br>
# Kelas   : TI-3A <br>

# %% [markdown]
# ## Tentang dataset
#
# Pada sebuah lembaga kemanusiaan berbasis teknologi informasi, dibentuk beberapa tim kemanusiaan yang bertugas untuk terjun ke masyarakat memberikan bantuan dalam bentuk aplikasi komputer atau layanan pelatihan IT.  Kegiatn tersebut dilaksanakan setiap tahun dengan ketentuan anggota organisasi tersebut dapat bergabung ke beberapa tim sebagai ketua atau anggota. Terdapat pula anggota yang sudah tidak aktif di organisasi tersebut (terhapus di database mereka —> label N/A).  Organisasi tersebut juga melakukan rekrutmen volunteer, namun tidak semua tim menggunakan bantuan volunteer. Hasil kegiatan dari setiap tim dapat diwujudkan ke dalam sebuah pengakuan hak cipta atau publikasi karya ilmiah atau publikasi berita di media massa.
#
# ## Ketentuan
# 1. Pengerjaan secara individu alias setiap mahasiswa!
# 2. Terdapat data dengan nilai #N/A, pertimbangkan cara terbaik untuk mengatasi nilai tersebut.
# 3. Tidak boleh ada duplikasi pekerjaan antar mahasiswa
# 4. Berikan penjelasan untuk setiap tahapan. Jangan hanya kode!
#
# ## Soal
# 1. Lakukan pemilahan data training dan testing yang sesuai dan proporsional dari data tersebut! (10 poin)
# 2. Tentukan data validasi! (10 poin)
# 3. Tentukan secara tepat kolom yang menjadi "label" (20 poin)
# 4. Terapkan dua jenis metode klasifikasi dan lakukan perbandingan akurasi  dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan! (20 poin)
# 5. Lakukan tunning hyperparameter berdasarkan hasil klasifikasi pada nomor 3 menggunakan metode Grid Search dan Random Search! Simpulkan parameter apa yang paling baik digunakan berdasarkan metode klasifikasi yang dipilih, dan berapa akurasinya. (40 poin)

# %%
import pandas as pd

df = pd.read_excel('data/dataset_quiz.xlsx')

df.head(100)
# Out:
#     id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0     7206.0       7214.0       6211.0       8602.0       7801.0          NaN
# 1     7214.0       7109.0       8402.0       7903.0       9202.0          NaN
# 2     5911.0       8201.0       8701.0       9101.0       9003.0          NaN
# 3     8402.0       7702.0       8602.0       8903.0       8903.0          NaN
# 4     8201.0       8305.0       5911.0       5903.0       8402.0          NaN
# ..       ...          ...          ...          ...          ...          ...
# 80    8803.0       8804.0       9102.0       8005.0       9303.0          NaN
# 81    6211.0       8901.0       9003.0       9303.0       9007.0          NaN
# 82    8601.0       8903.0       8703.0          NaN          NaN          NaN
# 83    8703.0       8601.0       9202.0       9102.0       6204.0          NaN
# 84    8102.0       7109.0       5903.0       7206.0       8903.0          NaN
#
#    keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0              TIDAK                  0   2019  REGULER  TIDAK ADA
# 1              TIDAK                  0   2019  REGULER  TIDAK ADA
# 2              TIDAK                  0   2019  REGULER  TIDAK ADA
# 3              TIDAK                  0   2019  REGULER  TIDAK ADA
# 4              TIDAK                  0   2019  REGULER  TIDAK ADA
# ..               ...                ...    ...      ...        ...
# 80                YA                  3   2022  REGULER  TIDAK ADA
# 81                YA                  3   2022  REGULER  TIDAK ADA
# 82                YA                  3   2022  REGULER  TIDAK ADA
# 83                YA                  3   2022  REGULER  TIDAK ADA
# 84             TIDAK                  0   2022  REGULER  TIDAK ADA
#
#    jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# 0         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 1         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 2         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 3         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 4         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# ..              ...         ...         ...               ...
# 80        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 81        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 82        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 83        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 84        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
#
#    status_luaran_lain
# 0           TIDAK ADA
# 1           TIDAK ADA
# 2           TIDAK ADA
# 3           TIDAK ADA
# 4           TIDAK ADA
# ..                ...
# 80          TIDAK ADA
# 81          TIDAK ADA
# 82          TIDAK ADA
# 83          TIDAK ADA
# 84          TIDAK ADA
#
# [85 rows x 16 columns]

# %% [markdown]
# ### Mengatasi nilai N/A

# %%
df.isnull().sum()
# Out:
# id_ketua               3
# id_anggota1            5
# id_anggota2            4
# id_anggota3            3
# id_anggota4           13
# id_anggota5           84
# keterlibatan_vltr      0
# jml_vltr_terlibat      0
# tahun                  0
# skema                  0
# luaran_hki             0
# jenis_luaran_hki       0
# potensi_hki            0
# luaran_lain            0
# jenis_luaran_lain      0
# status_luaran_lain     0
# dtype: int64

# %%
# Mengisi kolom null
from scipy.stats import mode

df['id_ketua'] = df['id_ketua'].fillna(df['id_ketua'].mode()[0])
df['id_anggota1'] = df['id_anggota1'].fillna(df['id_anggota1'].mode()[0])
df['id_anggota2'] = df['id_anggota2'].fillna(df['id_anggota2'].mode()[0])
df['id_anggota3'] = df['id_anggota3'].fillna(df['id_anggota3'].mode()[0])
df['id_anggota4'] = df['id_anggota4'].fillna(df['id_anggota4'].mode()[0])
df['id_anggota5'] = df['id_anggota5'].fillna(df['id_anggota5'].mode()[0])
# import numpy as np

# df = df.replace(np.nan, 0)

# %%
# Cek kolom null kembali
df.isnull().sum()
# Out:
# id_ketua              0
# id_anggota1           0
# id_anggota2           0
# id_anggota3           0
# id_anggota4           0
# id_anggota5           0
# keterlibatan_vltr     0
# jml_vltr_terlibat     0
# tahun                 0
# skema                 0
# luaran_hki            0
# jenis_luaran_hki      0
# potensi_hki           0
# luaran_lain           0
# jenis_luaran_lain     0
# status_luaran_lain    0
# dtype: int64

# %%
df.head(100)
# Out:
#     id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0     7206.0       7214.0       6211.0       8602.0       7801.0       8812.0
# 1     7214.0       7109.0       8402.0       7903.0       9202.0       8812.0
# 2     5911.0       8201.0       8701.0       9101.0       9003.0       8812.0
# 3     8402.0       7702.0       8602.0       8903.0       8903.0       8812.0
# 4     8201.0       8305.0       5911.0       5903.0       8402.0       8812.0
# ..       ...          ...          ...          ...          ...          ...
# 80    8803.0       8804.0       9102.0       8005.0       9303.0       8812.0
# 81    6211.0       8901.0       9003.0       9303.0       9007.0       8812.0
# 82    8601.0       8903.0       8703.0       8602.0       8901.0       8812.0
# 83    8703.0       8601.0       9202.0       9102.0       6204.0       8812.0
# 84    8102.0       7109.0       5903.0       7206.0       8903.0       8812.0
#
#    keterlibatan_vltr  jml_vltr_terlibat  tahun    skema luaran_hki  \
# 0              TIDAK                  0   2019  REGULER  TIDAK ADA
# 1              TIDAK                  0   2019  REGULER  TIDAK ADA
# 2              TIDAK                  0   2019  REGULER  TIDAK ADA
# 3              TIDAK                  0   2019  REGULER  TIDAK ADA
# 4              TIDAK                  0   2019  REGULER  TIDAK ADA
# ..               ...                ...    ...      ...        ...
# 80                YA                  3   2022  REGULER  TIDAK ADA
# 81                YA                  3   2022  REGULER  TIDAK ADA
# 82                YA                  3   2022  REGULER  TIDAK ADA
# 83                YA                  3   2022  REGULER  TIDAK ADA
# 84             TIDAK                  0   2022  REGULER  TIDAK ADA
#
#    jenis_luaran_hki potensi_hki luaran_lain jenis_luaran_lain  \
# 0         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 1         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 2         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 3         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 4         TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# ..              ...         ...         ...               ...
# 80        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 81        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 82        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 83        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
# 84        TIDAK ADA       TIDAK   TIDAK ADA         TIDAK ADA
#
#    status_luaran_lain
# 0           TIDAK ADA
# 1           TIDAK ADA
# 2           TIDAK ADA
# 3           TIDAK ADA
# 4           TIDAK ADA
# ..                ...
# 80          TIDAK ADA
# 81          TIDAK ADA
# 82          TIDAK ADA
# 83          TIDAK ADA
# 84          TIDAK ADA
#
# [85 rows x 16 columns]

# %% [markdown]
# ## Soal 1 <br>
# Pemilahan data training dan testing yang sesuai dan proporsional

# %%
# Split data
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:1:1
df_train, df_unseen = train_test_split(df, test_size=0.2, random_state=0)

# Split lagi antara validasi dan testing
df_val, df_test = train_test_split(df_unseen, test_size=0.5, random_state=0)

# Cek masing-masing ukuran data
print(f'Jumlah data asli: {df.shape[0]}')
# cek data training
print(f'Jumlah data training: {df_train.shape[0]}')
# cek data testing
print(f'Jumlah data testing: {df_test.shape[0]}')

# Cek rasio tiap label
print('=========')
print(f'Jumlah label data asli:\n{df.keterlibatan_vltr.value_counts()}')
# cek rasio training
print(f'Jumlah label data training:\n{df_train.keterlibatan_vltr.value_counts()}')
# cek rasio testing
print(f'Jumlah label data testing:\n{df_test.keterlibatan_vltr.value_counts()}')
# Out:
# Jumlah data asli: 85
# Jumlah data training: 68
# Jumlah data testing: 9
# =========
# Jumlah label data asli:
# TIDAK    45
# YA       40
# Name: keterlibatan_vltr, dtype: int64
# Jumlah label data training:
# TIDAK    36
# YA       32
# Name: keterlibatan_vltr, dtype: int64
# Jumlah label data testing:
# TIDAK    6
# YA       3
# Name: keterlibatan_vltr, dtype: int64

# %% [markdown]
# ## Soal 2<br>
# Menentukan validasi data

# %%
# Cek ukuran validasi data
print(f'Jumlah data asli: {df.shape[0]}')
print(f'Jumlah data validasi: {df_val.shape[0]}')

# Cek rasio label validasi
print('=========')
print(f'Jumlah label data asli:\n{df.keterlibatan_vltr.value_counts()}')
print(f'Jumlah label data validasi:\n{df_val.keterlibatan_vltr.value_counts()}')
# Out:
# Jumlah data asli: 85
# Jumlah data validasi: 8
# =========
# Jumlah label data asli:
# TIDAK    45
# YA       40
# Name: keterlibatan_vltr, dtype: int64
# Jumlah label data validasi:
# YA       5
# TIDAK    3
# Name: keterlibatan_vltr, dtype: int64

# %% [markdown]
# ## Soal 3<br>
# Menentukan kolom yang menjadi "label"

# %%
# Mengubah data kategorial menjadi data numerik dengan menggunakan fungsi pada label encoder
from sklearn.preprocessing import LabelEncoder

# Inisiasi label encoder
encode = LabelEncoder()

# Menerapkan label encoder
df['keterlibatan_vltr'] = encode.fit_transform(df['keterlibatan_vltr'])
df['skema'] = encode.fit_transform(df['skema'])
df['luaran_hki'] = encode.fit_transform(df['luaran_hki'])
df['jenis_luaran_hki'] = encode.fit_transform(df['jenis_luaran_hki'])
df['potensi_hki'] = encode.fit_transform(df['potensi_hki'])
df['luaran_lain'] = encode.fit_transform(df['luaran_lain'])
df['jenis_luaran_lain'] = encode.fit_transform(df['jenis_luaran_lain'])
df['status_luaran_lain'] = encode.fit_transform(df['status_luaran_lain'])

# Cek hasil
df.head()
# Out:
#    id_ketua  id_anggota1  id_anggota2  id_anggota3  id_anggota4  id_anggota5  \
# 0    7206.0       7214.0       6211.0       8602.0       7801.0       8812.0
# 1    7214.0       7109.0       8402.0       7903.0       9202.0       8812.0
# 2    5911.0       8201.0       8701.0       9101.0       9003.0       8812.0
# 3    8402.0       7702.0       8602.0       8903.0       8903.0       8812.0
# 4    8201.0       8305.0       5911.0       5903.0       8402.0       8812.0
#
#    keterlibatan_vltr  jml_vltr_terlibat  tahun  skema  luaran_hki  \
# 0                  0                  0   2019      1           1
# 1                  0                  0   2019      1           1
# 2                  0                  0   2019      1           1
# 3                  0                  0   2019      1           1
# 4                  0                  0   2019      1           1
#
#    jenis_luaran_hki  potensi_hki  luaran_lain  jenis_luaran_lain  \
# 0                 1            2            0                  3
# 1                 1            2            0                  3
# 2                 1            2            0                  3
# 3                 1            2            0                  3
# 4                 1            2            0                  3
#
#    status_luaran_lain
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
df = df.iloc[:, 6:]
df.head()
# Out:
#    keterlibatan_vltr  jml_vltr_terlibat  tahun  skema  luaran_hki  \
# 0                  0                  0   2019      1           1
# 1                  0                  0   2019      1           1
# 2                  0                  0   2019      1           1
# 3                  0                  0   2019      1           1
# 4                  0                  0   2019      1           1
#
#    jenis_luaran_hki  potensi_hki  luaran_lain  jenis_luaran_lain  \
# 0                 1            2            0                  3
# 1                 1            2            0                  3
# 2                 1            2            0                  3
# 3                 1            2            0                  3
# 4                 1            2            0                  3
#
#    status_luaran_lain
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# maka disini kolom yang menjadi label adalah keterlibatan_vltr

# %% [markdown]
# ## Soal 4<br>
# Menerapkan dua jenis metode klasifikasi dan lakukan perbandingan akurasi dengan wajib melibatkan variabel keterlibatan volunteer sampai variabel luaran-luaran yang dihasilkan

# %%
X = df.iloc[:, 6:]
y = df['keterlibatan_vltr']

X.shape
# Out:
# (85, 10)

# %%
# Split data training dan testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier # import DT
from sklearn.metrics import accuracy_score, classification_report

# Mendefinisikan model Decision Tree Classifier
dt = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt.fit(X_train, y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

#  menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0

# %% [markdown]
# RandomForest

# %%
# import RandomForest
from sklearn.ensemble import RandomForestClassifier 

# Mendefinisikan model Random Forest Classifier
rf = RandomForestClassifier()

# Sesuaikan dt ke set training
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

#  menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0

# %% [markdown]
# ## Soal 5
# Melakukan tunning hyperparameter berdasarkan hasil klasifikasi pada nomor 3 menggunakan metode Grid Search dan Random Search

# %% [markdown]
# Grid Search

# %%
from sklearn.model_selection import RepeatedKFold

# inisiasi repated k-fold
cv = RepeatedKFold(n_splits=4, n_repeats=3, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# inisiasi model
dt = DecisionTreeClassifier()

# Definisikan hyperparameter yang akan digunakan
# sklearn menerima dalam bentuk dictionary
# nama hyperparamater HARUS SESUAI dengan dokumentasi sklearn
params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(5,11))
}

# inisiasi grid berdasarkan nilai repeated k-fold dan hyperparameter
grid = GridSearchCV(dt, param_grid=params, cv=cv)

# Fit / latih berdasarkan grid
# %timeit merupakan magic command didalam ipython notebook
# yang dapat kita gunakan untuk menghitung waktu komputasi
# cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# %timeit grid.fit(X, y)

# Evaluasi dengan score
score = grid.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {grid.best_params_}')
# Out:
# 606 ms ± 25.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 1.0
# Konfigurasi hyperparameter: {'criterion': 'gini', 'max_depth': 10}

# %% [markdown]
# Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# inisiasi model
dt = DecisionTreeClassifier()

# Definisikan hyperparameter yang akan digunakan
# sklearn menerima dalam bentuk dictionary
# nama hyperparamater HARUS SESUAI dengan dokumentasi sklearn
rs_space = {
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(5,11))
}

# inisiasi random berdasarkan nilai repeated k-fold dan hyperparameter
random = RandomizedSearchCV(dt, rs_space, cv=cv, scoring='accuracy')

# Fit / latih berdasarkan random
# %timeit merupakan magic command didalam ipython notebook
# yang dapat kita gunakan untuk menghitung waktu komputasi
# cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# %timeit random.fit(X, y)

# Evaluasi dengan score
score = random.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {random.best_params_}')
print('Score terbaik: '+str(random.best_score_))
# Out:
# 516 ms ± 16.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi: 1.0
# Konfigurasi hyperparameter: {'max_depth': 7, 'criterion': 'gini'}
# Score terbaik: 1.0

# %% [markdown]
# ## Simpulan <br>
#
# Berdasarkan hasil klasifikasi menggunakan metode Grid Search dan Random Search sama-sama menghasilkan nilai accuracy data 1.0. Namun jika menggunakan  Grid Search kombinasi dievaluasi, model dengan kumpulan parameter yang memberikan akurasi tertinggi dianggap yang terbaik. Jika menggunakan Random Search fungsi dievaluasi pada sejumlah konfigurasi acak dalam ruang parameter
